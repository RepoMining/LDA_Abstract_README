# %%
import sys
from gensim.utils import simple_preprocess

import gensim
from pprint import pprint
import spacy
import gensim.corpora as corpora
from gensim.models import TfidfModel
from gensim.models import LdaModel

print('Python %s on %s' % (sys.version, sys.platform))
sys.path.extend(['E:\\LDA_Abstract_README', 'E:/LDA_Abstract_README'])
from utils import load_data

n_topics = [10, 20, 27, 30]
n_docs = 10000


textPre_FilePath = "../data/readme_corpus.txt"
lda_ModelPath = "./readme_model/"


def sent_to_words(sentences):
    for sentence in sentences:
        yield gensim.utils.simple_preprocess(str(sentence), deacc=True)  # deacc=True removes punctuations

# Define functions for stopwords, bigrams, trigrams and lemmatization
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

def lemmatization(texts, notAllowed_postags=None):
    """https://spacy.io/api/annotation"""
    if notAllowed_postags is None:
        notAllowed_postags = ['ADJ', 'ADV']
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent))
        texts_out.append([token.lemma_ for token in doc if token.pos_ not in notAllowed_postags])
    return texts_out

data = load_data(textPre_FilePath)[:n_docs]
data_words = list(sent_to_words(data))
# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)

# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# NLTK Stop words
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use'])
# Remove Stop Words
data_words_nostops = remove_stopwords(data_words)

# Form Bigrams
data_words_bigrams = make_bigrams(data_words_nostops)

# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
nlp = spacy.load("en_core_web_sm", disable=['parser', 'ner'])

# Do lemmatization keeping only noun, adj, vb, adv
data_lemmatized = lemmatization(data_words_bigrams, notAllowed_postags=['ADJ', 'ADV'])


# Create Dictionary
id2word = corpora.Dictionary(data_lemmatized)

# Create Corpus
texts = data_lemmatized

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]

# 创建TF-IDF模型并应用于整个语料库
tfidf_model = TfidfModel(corpus)
corpus = tfidf_model[corpus]
# Out:
# Python 3.10.0 (tags/v3.10.0:b494f59, Oct  4 2021, 19:00:18) [MSC v.1929 64 bit (AMD64)] on win32
# [nltk_data] Downloading package stopwords to E:\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
n_t = 0
n_top_words = 10
models = []
for n_t in n_topics:
    lda = LdaModel.load(lda_ModelPath+'lda_readme'+str(n_t))
    models.append(lda)

# %% [markdown]
# # Top words

# %%
# Print the Keyword in the 10 topics
for model in models:
    pprint(model.print_topics(num_words=n_top_words))
# doc_lda = lda_model[corpus]
# Out:
# [(0,
#   '0.000*"phyre" + 0.000*"flownet" + 0.000*"tenni" + 0.000*"censu" + '
#   '0.000*"plate" + 0.000*"breast" + 0.000*"sparql" + 0.000*"tener" + '
#   '0.000*"raft" + 0.000*"vot"'),
#  (1,
#   '0.001*"mot" + 0.000*"lightgbm" + 0.000*"mathematica" + 0.000*"sde" + '
#   '0.000*"kalman" + 0.000*"micro_express" + 0.000*"floodsung" + '
#   '0.000*"multifit" + 0.000*"coqa" + 0.000*"pcrnet"'),
#  (2,
#   '0.005*"googl" + 0.005*"research" + 0.004*"git" + 0.003*"clone" + '
#   '0.003*"trunk_subdir" + 0.003*"foo_svn" + 0.003*"interest_subdir" + '
#   '0.002*"creativecommon" + 0.002*"histori" + 0.002*"recommend"'),
#  (3,
#   '0.000*"leakag" + 0.000*"banana_banana" + 0.000*"gqa" + 0.000*"coreset" + '
#   '0.000*"superresolut" + 0.000*"disast" + 0.000*"vilbert" + 0.000*"mia" + '
#   '0.000*"motif" + 0.000*"mpg_caption"'),
#  (4,
#   '0.009*"readm" + 0.008*"huggingfac" + 0.007*"co" + 0.007*"md" + '
#   '0.005*"transform" + 0.004*"timm" + 0.004*"maxvit" + 0.003*"ft" + '
#   '0.003*"doc" + 0.003*"vit"'),
#  (5,
#   '0.004*"darknet" + 0.004*"yolov" + 0.003*"cfg" + 0.001*"yolo" + '
#   '0.001*"exe_detector" + 0.001*"dropout_sparsifi" + 0.001*"cascad" + '
#   '0.001*"iou" + 0.001*"area_maxdet" + 0.001*"tg_salt"'),
#  (6,
#   '0.001*"mmlab_mmselfsup" + 0.001*"heroku" + 0.001*"nuscen" + '
#   '0.001*"mmselfsup" + 0.000*"john_johanson" + 0.000*"butterfli" + '
#   '0.000*"gaze" + 0.000*"app_wandb" + 0.000*"deepspeech" + 0.000*"ng"'),
#  (7,
#   '0.005*"garden" + 0.001*"badg_furi" + 0.001*"amr" + 0.001*"rashwan_le" + '
#   '0.001*"powershel_shell" + 0.001*"liu_jaeyoun" + 0.001*"hongkun_yu" + '
#   '0.001*"hou_jin" + 0.001*"chen_xianzhi" + 0.001*"yang_frederick"'),
#  (8,
#   '0.004*"model" + 0.004*"imag" + 0.003*"train" + 0.003*"py" + 0.003*"pdf" + '
#   '0.003*"network" + 0.003*"dataset" + 0.003*"path" + 0.002*"datum" + '
#   '0.002*"test"'),
#  (9,
#   '0.000*"probreg" + 0.000*"superpixel" + 0.000*"udac_drlnd" + 0.000*"sage" + '
#   '0.000*"univers_texa" + 0.000*"dpm" + 0.000*"tcn" + 0.000*"iou_iou" + '
#   '0.000*"ahixjn_blw" + 0.000*"svrg"')]
# [(0,
#   '0.001*"starcraft_ii" + 0.001*"pinn" + 0.001*"eeg" + 0.001*"orbit" + '
#   '0.000*"pymarl" + 0.000*"mcmc" + 0.000*"abbrevi" + 0.000*"cvae" + '
#   '0.000*"smac" + 0.000*"javascript"'),
#  (1,
#   '0.002*"ssd" + 0.002*"cascad" + 0.002*"capsul" + 0.002*"retinanet" + '
#   '0.002*"fco" + 0.001*"nuscen" + 0.001*"caff" + 0.001*"mobilenetv" + '
#   '0.001*"tg_salt" + 0.001*"landmark"'),
#  (2,
#   '0.003*"check_mark" + 0.002*"drug" + 0.001*"catalyst" + 0.001*"imgur" + '
#   '0.001*"poetri" + 0.001*"gridworld" + 0.001*"roug" + 0.001*"brain_tokyo" + '
#   '0.001*"confid_interv" + 0.001*"cora"'),
#  (3,
#   '0.005*"imag" + 0.005*"model" + 0.004*"train" + 0.004*"pdf" + '
#   '0.004*"network" + 0.004*"py" + 0.004*"dataset" + 0.003*"datum" + '
#   '0.003*"path" + 0.003*"test"'),
#  (4,
#   '0.003*"celeba" + 0.003*"triplet" + 0.002*"gcn" + 0.002*"jindongwang" + '
#   '0.002*"safeti" + 0.002*"optimis" + 0.002*"gurobi" + 0.001*"sketch" + '
#   '0.001*"bay" + 0.001*"iq"'),
#  (5,
#   '0.001*"salient" + 0.001*"rss" + 0.001*"hallucin" + 0.001*"superpixel" + '
#   '0.001*"barycent" + 0.001*"craft" + 0.000*"pix_pix" + 0.000*"ev" + '
#   '0.000*"bcn" + 0.000*"el"'),
#  (6,
#   '0.009*"garden" + 0.006*"tf" + 0.004*"tensorflow" + 0.004*"model" + '
#   '0.003*"badg_furi" + 0.002*"mmlab_mmselfsup" + 0.002*"user" + 0.002*"packag" '
#   '+ 0.002*"research" + 0.002*"os"'),
#  (7,
#   '0.004*"diffus" + 0.002*"pointnet" + 0.002*"modelnet" + 0.002*"gene" + '
#   '0.001*"lesion" + 0.001*"codecog_latex" + 0.001*"sensit" + 0.001*"fl" + '
#   '0.001*"dna" + 0.001*"compound"'),
#  (8,
#   '0.002*"bnn" + 0.001*"plant" + 0.001*"clevr" + 0.001*"snli" + 0.001*"ape" + '
#   '0.001*"espnet" + 0.001*"gestur" + 0.001*"chest_ray" + 0.001*"imbal" + '
#   '0.001*"kge"'),
#  (9,
#   '0.001*"cutout" + 0.001*"lightgbm" + 0.001*"grad_cam" + 0.001*"dart" + '
#   '0.001*"ode" + 0.001*"csi" + 0.001*"mae" + 0.001*"skipgram" + '
#   '0.001*"equilibrium" + 0.000*"theta"'),
#  (10,
#   '0.002*"mot" + 0.002*"segnet" + 0.001*"yelp" + 0.001*"gin" + '
#   '0.001*"omniglot" + 0.001*"dgl" + 0.001*"tile" + 0.001*"ct" + 0.001*"convex" '
#   '+ 0.001*"flower"'),
#  (11,
#   '0.012*"huggingfac" + 0.011*"co" + 0.008*"transform" + 0.006*"doc" + '
#   '0.002*"idx" + 0.002*"facebook" + 0.001*"bird" + 0.001*"caff" + 0.001*"knn" '
#   '+ 0.001*"maskrcnn_benchmark"'),
#  (12,
#   '0.002*"ood" + 0.001*"vizdoom" + 0.001*"hal" + 0.001*"shufflenet" + '
#   '0.001*"kd" + 0.001*"complextensor" + 0.001*"breast" + 0.001*"disast" + '
#   '0.000*"publaynet" + 0.000*"jain"'),
#  (13,
#   '0.001*"gh_reagent" + 0.001*"chess" + 0.001*"horizon" + 0.001*"meme" + '
#   '0.001*"circleci" + 0.001*"pac" + 0.001*"facebook" + 0.001*"codecov" + '
#   '0.001*"platform" + 0.001*"dqn"'),
#  (14,
#   '0.001*"snn" + 0.001*"wideresnet" + 0.001*"voxceleb" + 0.001*"dice" + '
#   '0.001*"pseudo" + 0.001*"selector" + 0.001*"wavelet" + 0.001*"coreset" + '
#   '0.001*"exposur" + 0.001*"ebay"'),
#  (15,
#   '0.011*"readm" + 0.010*"md" + 0.006*"timm" + 0.006*"maxvit" + 0.005*"ft" + '
#   '0.004*"vit" + 0.004*"rw" + 0.004*"patch" + 0.003*"huggingfac" + 0.003*"co"'),
#  (16,
#   '0.003*"market" + 0.003*"kornia" + 0.003*"dblp" + 0.001*"extractor" + '
#   '0.001*"sigma" + 0.001*"passag" + 0.001*"ep" + 0.001*"tr" + 0.001*"mpii" + '
#   '0.001*"processor"'),
#  (17,
#   '0.001*"bandit" + 0.001*"eye" + 0.001*"gat" + 0.001*"slam" + 0.001*"transit" '
#   '+ 0.001*"tsp" + 0.001*"lidar" + 0.001*"gati" + 0.001*"ro" + 0.001*"visdom"'),
#  (18,
#   '0.002*"carla" + 0.002*"gp" + 0.002*"insightfac" + 0.001*"arcfac" + '
#   '0.001*"dropout_sparsifi" + 0.001*"molecul" + 0.001*"gold" + 0.001*"mida" + '
#   '0.001*"foreground" + 0.001*"pgd"'),
#  (19,
#   '0.010*"googl" + 0.010*"research" + 0.007*"git" + 0.006*"clone" + '
#   '0.006*"interest_subdir" + 0.006*"trunk_subdir" + 0.006*"foo_svn" + '
#   '0.005*"creativecommon" + 0.004*"histori" + 0.004*"recommend"')]
# [(0,
#   '0.002*"imit" + 0.002*"forecast" + 0.001*"extractor" + 0.001*"starcraft_ii" '
#   '+ 0.001*"cs_searchtyp" + 0.001*"nce" + 0.001*"drone" + 0.001*"maml" + '
#   '0.001*"polit" + 0.001*"jalammar"'),
#  (17,
#   '0.014*"yolov" + 0.012*"cfg" + 0.012*"darknet" + 0.007*"voc" + 0.005*"yolo" '
#   '+ 0.003*"keypoint" + 0.003*"kinet" + 0.003*"carla" + 0.002*"exe_detector" + '
#   '0.002*"pjreddi"'),
#  (5,
#   '0.001*"physionet" + 0.001*"fco" + 0.001*"notion" + 0.001*"exercis" + '
#   '0.001*"emnist" + 0.001*"scala" + 0.001*"grab" + 0.000*"yqx" + 0.000*"panel" '
#   '+ 0.000*"corefer_resolut"'),
#  (9,
#   '0.004*"mmlab_mmselfsup" + 0.002*"crowd" + 0.002*"mmselfsup" + '
#   '0.001*"merlin" + 0.001*"para" + 0.001*"trt" + 0.001*"belief" + '
#   '0.001*"area_maxdet" + 0.001*"que" + 0.001*"rollout"'),
#  (22,
#   '0.002*"gh_reagent" + 0.001*"circleci" + 0.001*"meme" + 0.001*"codecov" + '
#   '0.001*"signatur" + 0.001*"platform" + 0.001*"facebook" + '
#   '0.001*"hate_speech" + 0.001*"offic" + 0.001*"dat"'),
#  (1,
#   '0.004*"pointnet" + 0.001*"hair" + 0.001*"charlesq_pointnet" + '
#   '0.001*"multifit" + 0.000*"guiba" + 0.000*"rqi_pointnet" + 0.000*"devito" + '
#   '0.000*"mrp" + 0.000*"multibert" + 0.000*"carneiro"'),
#  (11,
#   '0.004*"subspac" + 0.002*"omniglot" + 0.001*"timit" + '
#   '0.001*"dl_fbaipublicfil" + 0.001*"ptb" + 0.001*"lightgbm" + '
#   '0.001*"dictionari" + 0.001*"mida" + 0.001*"miniimagenet" + '
#   '0.001*"hallucin"'),
#  (7,
#   '0.001*"microscopi" + 0.001*"srd" + 0.000*"ivrl" + '
#   '0.000*"fluoresc_microscopi" + 0.000*"volatil" + 0.000*"yb_mo" + '
#   '0.000*"biaffin" + 0.000*"jdsr" + 0.000*"textit" + 0.000*"teapot"'),
#  (8,
#   '0.007*"torchvis" + 0.004*"check_mark" + 0.002*"forc" + 0.002*"capsul" + '
#   '0.002*"likelihood" + 0.002*"integ" + 0.002*"audio" + 0.002*"col" + '
#   '0.001*"libpng" + 0.001*"gat"'),
#  (21,
#   '0.020*"readm" + 0.017*"md" + 0.004*"diffus" + 0.004*"distil" + '
#   '0.004*"market" + 0.004*"xformer" + 0.003*"kornia" + 0.003*"dblp" + '
#   '0.003*"teacher" + 0.003*"jindongwang"'),
#  (6,
#   '0.005*"tweet" + 0.004*"defens" + 0.003*"cascad" + 0.002*"scannet" + '
#   '0.001*"fl" + 0.001*"plant" + 0.001*"dynet" + 0.001*"mpii" + 0.001*"leakag" '
#   '+ 0.001*"wd"'),
#  (24,
#   '0.002*"mtl" + 0.002*"bandit" + 0.002*"grad_cam" + 0.001*"poetri" + '
#   '0.001*"inject" + 0.001*"greedi" + 0.001*"react" + 0.001*"harmon" + '
#   '0.001*"plan_wireless" + 0.001*"singan"'),
#  (16,
#   '0.012*"googl" + 0.012*"research" + 0.009*"git" + 0.008*"clone" + '
#   '0.007*"interest_subdir" + 0.007*"foo_svn" + 0.007*"trunk_subdir" + '
#   '0.006*"creativecommon" + 0.006*"histori" + 0.005*"recommend"'),
#  (20,
#   '0.001*"sar" + 0.001*"eng" + 0.001*"superresolut" + 0.001*"udac_drlnd" + '
#   '0.001*"tednet" + 0.001*"mcd" + 0.001*"mil" + 0.001*"publaynet" + '
#   '0.001*"discrep" + 0.001*"fruit"'),
#  (26,
#   '0.004*"moco" + 0.003*"fpn" + 0.003*"storag_googleapi" + '
#   '0.002*"maskrcnn_benchmark" + 0.002*"squad" + 0.002*"ood" + 0.002*"mot" + '
#   '0.002*"wav" + 0.002*"sort" + 0.002*"tpu"'),
#  (4,
#   '0.015*"huggingfac" + 0.014*"co" + 0.011*"transform" + 0.007*"doc" + '
#   '0.003*"transport" + 0.002*"facebook" + 0.002*"iq" + 0.001*"furu_wei" + '
#   '0.001*"dna" + 0.001*"aclantholog"'),
#  (14,
#   '0.001*"ontolog" + 0.001*"gqa" + 0.001*"kd" + 0.001*"archiv" + '
#   '0.001*"facenet" + 0.001*"sparql" + 0.001*"hypernetwork" + 0.001*"trg" + '
#   '0.001*"reproduct" + 0.001*"hash"'),
#  (10,
#   '0.004*"caption" + 0.003*"gcn" + 0.003*"bia" + 0.003*"celeba" + '
#   '0.003*"gamma" + 0.003*"energi" + 0.003*"concept" + 0.003*"track" + '
#   '0.003*"dropbox" + 0.003*"diver"'),
#  (12,
#   '0.012*"garden" + 0.007*"tf" + 0.005*"model" + 0.005*"tensorflow" + '
#   '0.004*"badg_furi" + 0.003*"user" + 0.003*"packag" + 0.003*"research" + '
#   '0.003*"os" + 0.002*"tensorboard"'),
#  (23,
#   '0.002*"cgan" + 0.002*"stereo" + 0.002*"imput" + 0.002*"voxceleb" + '
#   '0.001*"vizdoom" + 0.001*"ode" + 0.001*"hing" + 0.001*"yoon" + '
#   '0.001*"residu" + 0.001*"subtask"')]
# [(0,
#   '0.004*"pointnet" + 0.003*"modelnet" + 0.003*"scannet" + 0.002*"voxel" + '
#   '0.001*"shapenet" + 0.001*"geo" + 0.001*"udac_drlnd" + 0.001*"colmap" + '
#   '0.001*"charlesq_pointnet" + 0.001*"clarif"'),
#  (11,
#   '0.009*"torchvis" + 0.002*"libpng" + 0.002*"voxceleb" + 0.001*"cmake" + '
#   '0.001*"lightgbm" + 0.001*"manag_rhel" + 0.001*"accimag" + '
#   '0.001*"respons_permiss" + 0.001*"swag" + 0.001*"markov"'),
#  (24,
#   '0.002*"grad_cam" + 0.002*"gat" + 0.001*"breast_cancer" + 0.001*"patent" + '
#   '0.001*"probreg" + 0.001*"theta" + 0.001*"selfi" + 0.001*"supernet" + '
#   '0.001*"vggface" + 0.001*"icassp"'),
#  (19,
#   '0.002*"iq" + 0.001*"pm" + 0.001*"trt" + 0.001*"ant" + 0.001*"inject" + '
#   '0.001*"tada" + 0.001*"ontolog" + 0.001*"membership" + 0.001*"slowfast" + '
#   '0.001*"kmedoid"'),
#  (26,
#   '0.001*"ode" + 0.001*"shufflenet" + 0.001*"bertmodel" + 0.001*"cocotalk" + '
#   '0.001*"soccer" + 0.000*"cider" + 0.000*"srresnet" + 0.000*"pami" + '
#   '0.000*"apprais" + 0.000*"lap"'),
#  (2,
#   '0.003*"drug" + 0.002*"dynet" + 0.001*"tt" + 0.001*"mathematica" + '
#   '0.001*"xai" + 0.001*"gpflow_gpflow" + 0.001*"raft" + 0.001*"semantickitti" '
#   '+ 0.001*"dispar" + 0.001*"yfcc"'),
#  (25,
#   '0.006*"gym" + 0.005*"replay" + 0.004*"mmlab_mmselfsup" + 0.003*"dqn" + '
#   '0.002*"trial" + 0.002*"snn" + 0.002*"tile" + 0.002*"mmselfsup" + '
#   '0.002*"visdom" + 0.001*"sac"'),
#  (15,
#   '0.025*"readm" + 0.021*"md" + 0.004*"kinet" + 0.003*"bnn" + 0.002*"ro" + '
#   '0.002*"fairseq" + 0.002*"al" + 0.002*"stereo" + 0.002*"wav_vec" + '
#   '0.002*"clevr"'),
#  (22,
#   '0.004*"brat" + 0.002*"tumor" + 0.002*"brain_tumor" + 0.002*"dice" + '
#   '0.001*"slice" + 0.001*"ship" + 0.001*"struct" + 0.001*"modal" + '
#   '0.001*"hair" + 0.001*"micro_express"'),
#  (23,
#   '0.005*"imag" + 0.005*"model" + 0.004*"train" + 0.004*"pdf" + '
#   '0.004*"network" + 0.004*"py" + 0.004*"dataset" + 0.003*"path" + '
#   '0.003*"datum" + 0.003*"test"'),
#  (27,
#   '0.002*"tg_salt" + 0.001*"smile" + 0.001*"salt" + 0.001*"ga" + 0.001*"film" '
#   '+ 0.001*"corenlp" + 0.001*"fragment" + 0.001*"mle" + 0.001*"meti" + '
#   '0.001*"reuter"'),
#  (3,
#   '0.004*"dblp" + 0.004*"kornia" + 0.003*"pneumonia" + 0.003*"alt" + '
#   '0.002*"disea" + 0.002*"manipul" + 0.002*"tr" + 0.002*"reg" + '
#   '0.002*"chexnet" + 0.002*"ray"'),
#  (13,
#   '0.004*"moco" + 0.002*"imgur" + 0.002*"physionet" + 0.001*"tenni" + '
#   '0.001*"plate" + 0.000*"analys" + 0.000*"swav" + 0.000*"drlnd" + '
#   '0.000*"srgan" + 0.000*"zo_bcd"'),
#  (20,
#   '0.004*"client" + 0.002*"wasserstein" + 0.002*"expans" + 0.002*"hrnet" + '
#   '0.002*"salient" + 0.002*"sc" + 0.002*"ptb" + 0.002*"mpii" + '
#   '0.002*"artifact" + 0.002*"hop"'),
#  (28,
#   '0.004*"mxnet" + 0.004*"jindongwang" + 0.002*"gene" + 0.002*"uniti" + '
#   '0.002*"ffhq" + 0.001*"cpn" + 0.001*"stylegan" + 0.001*"uniti_technolog" + '
#   '0.001*"waymo" + 0.001*"lexicon"'),
#  (6,
#   '0.002*"dna" + 0.002*"homographi" + 0.001*"piano" + 0.001*"extractor" + '
#   '0.001*"imbal" + 0.001*"writer" + 0.001*"subgraph" + 0.001*"jain" + '
#   '0.001*"ev" + 0.001*"kumar"'),
#  (21,
#   '0.004*"sentiment" + 0.002*"gin" + 0.002*"dgl" + 0.002*"forecast" + '
#   '0.001*"hrnet_hrnet" + 0.001*"sd" + 0.001*"composition" + 0.001*"breast" + '
#   '0.001*"pyg" + 0.001*"deepspeech"'),
#  (18,
#   '0.012*"research" + 0.012*"googl" + 0.009*"git" + 0.007*"clone" + '
#   '0.007*"foo_svn" + 0.007*"trunk_subdir" + 0.007*"interest_subdir" + '
#   '0.006*"creativecommon" + 0.005*"histori" + 0.005*"recommend"'),
#  (5,
#   '0.002*"particl" + 0.002*"mtl" + 0.001*"occlus" + 0.001*"mcd" + '
#   '0.001*"fiber" + 0.001*"davi" + 0.001*"appl_orang" + 0.001*"mil" + '
#   '0.001*"poet" + 0.001*"fruit"'),
#  (9,
#   '0.004*"carla" + 0.002*"selector" + 0.001*"cs_vmnih" + 0.001*"foreground" + '
#   '0.001*"tagger" + 0.001*"shapley_valu" + 0.001*"frcn" + 0.001*"distractor" + '
#   '0.001*"sdp" + 0.001*"hmm"')]

# %% [markdown]
# # UMASS

# %%
import numpy as np
from gensim.models import CoherenceModel
import matplotlib.pyplot as plt
measures = []

u_mass_value = []
for i, model in enumerate(models):
    # Compute Coherence Score
    coherence_model_lda = CoherenceModel(model=model, texts=data_lemmatized, dictionary=id2word, coherence='u_mass')
    coherence_lda = coherence_model_lda.get_coherence()
    u_mass_value.append(coherence_lda)
    measures.append([])
    measures[i].append(coherence_lda)

plt.figure()
plt.plot(n_topics, np.array(u_mass_value), label="UMASS")
for i in range(len(n_topics)):
    plt.text(n_topics[i], u_mass_value[i], str(u_mass_value[i])[:7], ha='center', va='bottom')
plt.xticks(n_topics)
plt.title('UMASS')
plt.legend()
plt.show()

# %% [markdown]
# # NPMI

# %%
import numpy as np
from gensim.models import CoherenceModel
import matplotlib.pyplot as plt

u_npmi_value = []
for i, model in enumerate(models):
    # Compute Coherence Score
    coherence_model_lda = CoherenceModel(model=model, texts=data_lemmatized, dictionary=id2word, coherence='c_npmi')
    coherence_lda = coherence_model_lda.get_coherence()
    u_npmi_value.append(coherence_lda)
    measures[i].append(coherence_lda)

plt.figure()
plt.plot(n_topics, np.array(u_npmi_value), label="NPMI")
for i in range(len(n_topics)):
    plt.text(n_topics[i], u_npmi_value[i], str(u_npmi_value[i])[:7], ha='center', va='bottom')
plt.xticks(n_topics)
plt.title('NPMI')
plt.legend()
plt.show()

# %% [markdown]
# # Coherence Value

# %%
import numpy as np
from gensim.models import CoherenceModel
import matplotlib.pyplot as plt

coherence_value = []
for i, model in enumerate(models):
    # Compute Coherence Score
    coherence_model_lda = CoherenceModel(model=model, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
    coherence_lda = coherence_model_lda.get_coherence()
    coherence_value.append(coherence_lda)
    measures[i].append(coherence_lda)

plt.figure()
plt.plot(n_topics, np.array(coherence_value), label="Topic Coherence")
for i in range(len(n_topics)):
    plt.text(n_topics[i], coherence_value[i], str(coherence_value[i])[:7], ha='center', va='bottom')
plt.xticks(n_topics)
plt.title('Topic Coherence')
plt.legend()
plt.show()

# %%
import pandas as pd

performance = pd.DataFrame(measures, columns=['UMASS', 'NPMI', "Topic Coherence"])
performance
