# %%
import sys
from gensim.utils import simple_preprocess
from utils import load_data
import gensim
from pprint import pprint
import spacy
import gensim.corpora as corpora
from gensim.models import TfidfModel
from gensim.models import LdaModel

print('Python %s on %s' % (sys.version, sys.platform))
sys.path.extend(['E:\\LDA_Abstract_README', 'E:/LDA_Abstract_README'])

n_topics = [10, 20, 27, 30]


textPre_FilePath = "../data/abstract_corpus.txt"
lda_ModelPath = "./abstract_model/"


def sent_to_words(sentences):
    for sentence in sentences:
        yield gensim.utils.simple_preprocess(str(sentence), deacc=True)  # deacc=True removes punctuations

# Define functions for stopwords, bigrams, trigrams and lemmatization
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

def lemmatization(texts, notAllowed_postags=None):
    """https://spacy.io/api/annotation"""
    if notAllowed_postags is None:
        notAllowed_postags = ['ADJ', 'ADV']
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent))
        texts_out.append([token.lemma_ for token in doc if token.pos_ not in notAllowed_postags])
    return texts_out

data = load_data(textPre_FilePath)[351:361]
data_words = list(sent_to_words(data))
# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)

# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# NLTK Stop words
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use'])
# Remove Stop Words
data_words_nostops = remove_stopwords(data_words)

# Form Bigrams
data_words_bigrams = make_bigrams(data_words_nostops)

# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
nlp = spacy.load("en_core_web_sm", disable=['parser', 'ner'])

# Do lemmatization keeping only noun, adj, vb, adv
data_lemmatized = lemmatization(data_words_bigrams, notAllowed_postags=['ADJ', 'ADV'])


# Create Dictionary
id2word = corpora.Dictionary(data_lemmatized)

# Create Corpus
texts = data_lemmatized

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]

# tfidf_model = TfidfModel(corpus)
# corpus = tfidf_model[corpus]

models = []
for n_t in n_topics:
    lda = LdaModel.load(lda_ModelPath+'lda_abstract'+str(n_t))
    models.append(lda)
# Out:
# Python 3.10.0 (tags/v3.10.0:b494f59, Oct  4 2021, 19:00:18) [MSC v.1929 64 bit (AMD64)] on win32
# [nltk_data] Downloading package stopwords to E:\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import re
# Print the Keyword in the 10 topics
import pandas as pd
model_outputs = []
for model in models:
    model_outputs.append(model.print_topics(num_topics=30, num_words=10))

models_topics = []
pattern = r'"(.*?)"'
for output in model_outputs:
    models_topics.append([])
    for topics in output:
        words = re.findall(pattern, topics[1])
        models_topics[-1].append(words)
pd.DataFrame(models_topics)
# Out:
#                                                   0   \
# 0  [student, teacher, ner, tweet, session, gestur...
# 1  [ner, composition, comprehen, price, genom, il...
# 2  [norm, imput, cam, curvatur, subword, cp, ci, ...
# 3  [view, fusion, rank, tensor, rotat, descriptor...
#
#                                                   1   \
# 0  [kg, composition, parti, kb, beta, gene, extra...
# 1  [session, citat, parti, continu, mobilenet, ga...
# 2  [waveform, composition, tabl, column, fingerpr...
# 3  [tracker, lesion, anim, keyword, tabl, mot, ma...
#
#                                                   2   \
# 0  [equivari, waveform, price, dictionari, star, ...
# 1  [instrument, surrog, hate_speech, dictionari, ...
# 2  [formula, conform, cgan, heatmap, logic, algeb...
# 3  [brain_tumor, tumor, site, da, brat, emb, era,...
#
#                                                   3   \
# 0  [equilibrium, dr, theorem, ct, ridg, newton, m...
# 1  [bit, entropi, layout, foundat, gpt, tabl, rem...
# 2  [rl, molecul, suit, option, parameter, script,...
# 3  [reid, induct, crop, person_identif, sde, mult...
#
#                                                   4   \
# 0  [protein, gait, pi, genom, contact, cd, sde, b...
# 1  [salienc, keypoint, edit, corpora, player, tra...
# 2  [toolkit, ode, disc, cortex, inherit, sac, tur...
# 3  [skeleton, transcript, waveform, patholog, asr...
#
#                                                   5   \
# 0  [registr, simplif, mot, reaction, induct, driv...
# 1  [model, imag, network, task, method, languag, ...
# 2  [wikipedia, star, hoi, read, corefer, sde, asc...
# 3  [ssl, beta, subword, sport, har, satellit, now...
#
#                                                   6   \
# 0  [caption, summar, review, anomali, road, summa...
# 1  [signatur, star, shortcut, sod, repair, reddit...
# 2  [explan, style, trajectori, energi, textur, ca...
# 3  [music, correspond, registr, kg, mri, ray, pla...
#
#                                                   7   \
# 0  [hash, fingerprint, epsilon, hsi, homolog, mal...
# 1  [emot, sgd, gestur, oracl, variant, burden, gr...
# 2  [tag, pi, smartphon, lie, atom, glass, termino...
# 3  [blur, logic, log_likelihood, galleri, isomorp...
#
#                                                   8   \
# 0  [model, imag, network, task, method, languag, ...
# 1  [beam, conflict, bo, greedi, dst, csi, smartph...
# 2  [rnn, recurr, redund, dp, absolut, obtain, del...
# 3  [ood, forecast, mention, gp, imbal, ode, likel...
#
#                                                   9   ...  \
# 0  [skeleton, reid, independ, man, cgan, ib, quan...  ...
# 1  [ood, vit, mot, occup, temperatur, band, heatm...  ...
# 2  [independ, dg, temperatur, probe, homographi, ...  ...
# 3  [realiz, ace, mrf, manufactur, multilay_percep...  ...
#
#                                                   20  \
# 0                                               None
# 1                                               None
# 2  [memor, gestur, compen, scikit, kd, abus, math...
# 3  [quantum, mix, quantum_circuit, pronunci, mpc,...
#
#                                                   21  \
# 0                                               None
# 1                                               None
# 2  [person, ct, reid, hop, i, ad, d, person_ident...
# 3  [sketch, job, atom, draw, glass, disagr, grasp...
#
#                                                   22  \
# 0                                               None
# 1                                               None
# 2  [viewpoint, kg, paint, mlp, eye, harmon, drl, ...
# 3  [summar, summari, ner, tweet, worker, custom, ...
#
#                                                   23  \
# 0                                               None
# 1                                               None
# 2  [cd, sport, plastic, doctor, ga, ace, fair, co...
# 3  [equilibrium, extrapol, driver, hypernetwork, ...
#
#                                                   24  \
# 0                                               None
# 1                                               None
# 2  [sr, lesion, denois, po, bound, shadow, lr, hr...
# 3  [model, imag, network, task, method, languag, ...
#
#                                                   25  \
# 0                                               None
# 1                                               None
# 2  [emot, inspect, hash, request, homolog, analyz...
# 3  [sgd, gcn, phone, momentum, curvatur, encourag...
#
#                                                   26  \
# 0                                               None
# 1                                               None
# 2  [model, imag, network, task, method, languag, ...
# 3  [mt, moder, minima, homolog, quadratur, pca, c...
#
#                                                   27  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3  [actor, emerg, discour, return, fingerprint, r...
#
#                                                   28  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3  [keypoint, learner, dialog, conver, complet, f...
#
#                                                   29
# 0                                               None
# 1                                               None
# 2                                               None
# 3  [lm, drug, squar, analog, center, dictionari, ...
#
# [4 rows x 30 columns]

# %%
doc_topics = []
for i, model in enumerate(models):
    topics_dis = []
    for doc in corpus:
        model_words = models_topics[i]
        topic_idx = max(model.get_document_topics(doc), key=lambda item: item[1])[0]
        model_words = model_words[topic_idx]
        topics = []
        doc_words = [id2word[word_id] for word_id, _ in doc]
        for doc_word in doc_words:
            for model_word in model_words:
                if model_word == doc_word:
                    topics.append(model_word)
        topics_dis.append(topics)
    doc_topics.append(topics_dis)

model_doc_topic = pd.DataFrame(doc_topics)
model_doc_topic.index = ["10 Topics", "20 Topics", "27 Topics", "30 Topics"]
columns = []
for i in range(10):
    columns.append("Abstract " + str(i+1))
model_doc_topic.columns = columns
model_doc_topic
# Out:
#                             Abstract 1             Abstract 2  \
# 10 Topics  [approach, method, network]  [imag, languag, task]
# 20 Topics  [approach, method, network]  [imag, languag, task]
# 27 Topics  [approach, method, network]  [imag, languag, task]
# 30 Topics  [approach, method, network]  [imag, languag, task]
#
#                 Abstract 3                     Abstract 4  \
# 10 Topics  [method, model]  [method, network, imag, task]
# 20 Topics  [method, model]  [method, network, imag, task]
# 27 Topics  [method, model]  [method, network, imag, task]
# 30 Topics  [method, model]  [method, network, imag, task]
#
#                           Abstract 5               Abstract 6  \
# 10 Topics  [approach, method, model]  [method, network, task]
# 20 Topics  [approach, method, model]  [method, network, task]
# 27 Topics  [approach, method, model]  [method, network, task]
# 30 Topics  [approach, method, model]  [method, network, task]
#
#                                      Abstract 7                Abstract 8  \
# 10 Topics  [approach, datum, featur, represent]  [network, languag, task]
# 20 Topics  [approach, datum, featur, represent]  [network, languag, task]
# 27 Topics  [approach, datum, featur, represent]  [network, languag, task]
# 30 Topics  [approach, datum, featur, represent]  [network, languag, task]
#
#                                    Abstract 9     Abstract 10
# 10 Topics  [method, network, task, represent]  [method, imag]
# 20 Topics  [method, network, task, represent]  [method, imag]
# 27 Topics  [method, network, task, represent]  [method, imag]
# 30 Topics  [method, network, task, represent]  [method, imag]
