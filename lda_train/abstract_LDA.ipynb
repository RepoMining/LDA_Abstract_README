# %%
n_topics = [10, 20, 27, 30]
n_docs = 10000
textPre_FilePath = "../data/abstract_corpus.txt"
tf_ModelPath = "../abstract_model/abstract_tf.pt"
tfidf_ModelPath = "../abstract_model/abstract_tfidf.pt"
lda_ModelPath = "../abstract_model/abstract_"

# %%
from utils import load_data
import random
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from joblib import dump, load
from sklearn.decomposition import LatentDirichletAllocation
docLst = random.choices(load_data(textPre_FilePath), k=n_docs)
docLst
# Out:
# ['surg pre model user weight model dataset weight task choic question pre weight secur threat paper show construct weight attack pre weight vulner backdoor attack manipul model predict keyword show regular method call rippl initi procedur call surgeri attack knowledg dataset procedur experi classif toxic detect spam detect pose threat defens attack reproduc experi github com neulab rippl\n',
#  'paper bottom stage bodi estim call point regress hprnet standard bodi estim locat joint bodi bodi estim locat keypoint face hand foot varianc problem need varianc bodi part point represent bodi part locat keypoint part face refer center part locat person center addit stage method predict bodi time number peopl imag coco wholebodi hprnet bottom method detect bodi part bodi face hand state art result hand keypoint detect code model http github com hprnet\n',
#  'dml line research similar approach year field benefit progress diverg train protocol choic comparison refer point revisit dml function paramet choic mini batch process comparison dml satur literatur analysi correl space densiti compress gener perform dml model insight train regular perform rank model benchmark dataset wandb repo http github com confuseziu learn pytorch\n',
#  'wikidata commun varieti applic qualiti result paper analyz qualiti statement practic commun indic qualiti wikidata commun consensu knowledg statement qualiti statement constraint violat combin indic qualiti statement challeng entiti tripl type rule distinct find complement effort commun data qualiti user editor mistak\n',
#  'paper propos method step network rsn aggreg size level featur represent level inform result precis keypoint local output featur perform tackl problem attent mechan refin machin prm trade represent output featur keypoint locat place coco keypoint challeng state art result benchmark train data model model test dev test dataset model test dev test challeng sourc code research http github com caiyuanhao1998 rsn\n',
#  'issu analysi captur phase depend frequenc represent signal properti network way time seri imag network layer filter frequenc phase act phase coeffici descriptor space frequenc phase phase filter oper phase harmon transform phase prove defin bi represent correl harmon coeffici structur depend frequenc filter signal wavelet coeffici phase correl represent\n',
#  'densiti estim problem statist machin studi densiti estim model power network gan estim densiti valu densiti estim condit transform latent space data space roundtrip map seri experi achiev state art perform divers rang densiti estim task\n',
#  'process layer extens process remain approxim number locat layer paper locat data induc input distribut reduc paramet cost perform degrad result regress problem modif dgp train scheme induc input\n',
#  'paper determin bound lipschitz constant network activ function constant affin relu max function result network bound method insight bound track zero element composit affin relu function approach network exampl network lipschitz bound lipschitz bound bound classif network result bound perturb network vgg\n',
#  'network imag import understand mechan model system applic surveil access control method match imag featur vector structur imag paper method transpar method featur vector comparison strategi embed featur map imag enabl model metric way similar imag part wise contribut similar method model shelf backbon network method method benchmark cub200 cars196 stanford onlin product improv method interpret code http github com wl zhao diml\n',
#  'attent compon transform success languag process henc attent capabl transform parallel attent weight phenomena paper attent weight factor output attent analysi factor norm vector find analys transform machin translat system studi pay attent token word align attent mechan find insight work transform\n',
#  'method model imag counterpart approach result test set paper deblur meta test time adapt ground truth scene ground truth infer time world scenario leverag video use patch ground truth model extract blur input transfer pseudo sharp pseudo patch test time adapt gradient result deblur meta state art model red dataset\n',
#  'domain adapt leverag data sourc domain target domain variant domain adapt assum presenc class paper studi focu abil travers domain gap state art method perform drop presenc domain gap dataset pac framework domain gap lie inform network sampl class confus sourc target domain influenc sampl altern converg experi offic offic home pac dataset superior method comparison state art code http github com separ\n',
#  'fraction oper network multipl convolut layer end cost approxim multipl layer multipl layer product network circuit edg weight data spn multipl addit oper budget number multipl oper method knowledg distil imag classif dnn languag dnn lstm kind reduct number multipl perform precis model framework rediscov multipl time matric multipl\n',
#  'action soccer player game aspect player recruit process metric address task focu action shot goal account action paper introduc languag player action framework type player action game outcom account action soccer player action valu defens contribut show approach consid inform player evalu metric number use case style character season competit\n',
#  'detect step imag task multi agent reinforc c marl system landmark brain imag enabl agent commun channel commun signal weight architectur agent brain dataset reson ultrasound experi agent commun outperform approach agent\n',
#  'research time seri similar measur method indic time seri plethora parametr task hand learn approach domain imag sentenc similar paper propos textit neuralwarp measur model time seri indic represent space function level network time seri valu result neuralwarp outperform un model life dataset\n',
#  'word represent model variabl hmm nlp applic depend tree induct problem tree markov model function variabl transit emiss compon inform grain distinct word applic word represent task entiti recognit frame identif observ improv function inform case result state art represent method relationship model latter self evid\n',
#  'introduc approach build languag model explor skip gram model kneser ney approach languag model interpol order model case paper motiv approach experi text corpora demonstr languag model reduct perplex comparison languag model kneser ney behaviour languag corpu improv strength approach abil cope spars train data train data kb yield improv reduct perplex\n',
#  'knowledg graph kg role recommend system network model theme knowledg recommend kgr defici gnn kgr model problem perform drop extent success contrast mine signal data paper focu kg recommend propos multi level cross view mechan contrast learn method view data augment corrupt graph view recommend level view level view item view item entiti view item entiti view mcclk henc perform view level graph featur structur inform self manner view k neighbor knn item item graph construct modul captur item item relat work experi benchmark dataset perform method state art implement github com cciiplab mcclk\n',
#  'video method pipelin e imag text stream gener result method match paradigm pipelin paper sequenc end end video detect recognit framework transdetr transdetr advantag match paradigm frame transdetr track queri queri sequenc frame transdetr end video text framework sub task detect recognit experi video text dataset video icdar2015 video minetto youtub video text transdetr achiev state art perform improv spot task transdetr github com weijiawu transdetr\n',
#  'practic network number paramet wisdom trade model complex data aim address discrep optim spars recoveri perspect consid gener properti layer relu network regular regular assumpt show relu network number paramet model data recoveri model relu network variant connect normal layer isometri condit recoveri neuron data show exist phase transit network model ratio number sampl recoveri probabl probabl network spars model label transit phenomenon experi\n',
#  'network solut cf item interact graph idea gnn recommend system messag item interact edg refin embed recommend model qualiti train data represent user prefer behavior data recommend scenario exhibit distribut represent perform gnn model paper sht self transform framework sht augment represent relationship way graph cf paradigm maintain effect user item transform network context cross view self compon data augment item interact graph enhanc robust recommend system experi sht perform state art baselin ablat studi represent abil sht recommend framework data sparsiti nois issu sourc code evalu dataset github com akaxlh sht\n',
#  'success infer field implement differenti ad comput gradient object ad techniqu tool gradient precis machin learn model gradient descent comput memori minibatch gradient optim framework approach differenti rad gradient estim memori return varianc examin limit approach argu problem structur benefit rad techniqu varieti network architectur memori budget rad iter batch size feedforward network number recurr network comput use memori gradient method control paramet reaction diffus fission reactor\n',
#  'challeng fraud activ minor class proport data data set fraud case fraud data predict major group fraud remain discuss techniqu problem data sampl minor class frequent problem data presenc anomali observ data techniqu sampl detect algorithm spoil analysi tool anomali detect statist aim outlier major data data observ paper version combin approach problem data presenc outlier method achiev presenc fraud case anomali perform techniqu data set structur data sourc code robros algorithm\n',
#  'imag gener model model output case model evalu process ggm suffer limit score model select case fail edg node featur perform work mitig issu domain metric end studi ggm metric network metric model imag embed task network power network graph represent metric featur gnn design metric abil measur divers fidel effici quantiti sampl random gnn metric pre metric metric evalu practic enabl abil dissimilar set code github com mlrg ggm metric\n',
#  'polici address issu trade off equal product well mechan design problem polici design object polici lever respons actor object world polici simul realiti gap g calibr issu approach set polici lever measur yield polici behavior exampl henc optim polici world scenario economist framework enabl polici design reinforc rl data simul framework stringenc state polici subsidi e g covid simul data polici rl welfar health outcom outcom g polici chang recoveri vaccin rate calibr error infect rate world adopt machin method rl ai simul result guid polici design welfar complex world\n',
#  'document represent retriev relev document pre index support ad hoc search mismatch problem rank model pre languag model problem queri infer cost trade effect effici trade propos encod model spars retriev document encod represent encod encod role import term match ii term match train strategi encod intervent train result benchmark outperform encod rank model\n',
#  'class imbal problem issu represent attent commun imbal studi quantiti exampl class quantiti imbal argu graph data sourc imbal properti node node term role graph topolog imbal work topolog imbal issu characterist caus threat classif view quantiti topolog imbal issu influenc shift phenomenon propag algorithm analysi devis influenc conflict detect measur degre graph topolog imbal model method renod address topolog imbal issu influenc node posit class boundari experi generaliz method topolog imbal issu semi classif analysi unveil sensit network imbal perspect gnn architectur\n',
#  'discrep comput vision scale model state art perform model applic paper address issu gap type model investig aim method identifi recip state art scale model practic demonstr distil tool size model perform design choic effect distil contribut identif design literatur find studi demonstr compel result vision dataset state art resnet model imagenet accuraci\n',
#  'signatur verif task applic task hand featur genuin one deform verif problem stage learn framework represent writer osv imag reconstruct network encod decod architectur attent mechan imag patch encod backbon fine projector head framework optim triplet loss sampl writer class well writer sampl counterpart sampl writer cross writer set result space knowledg work framework stage framework signatur dataset state art method method result piec work code http github com soumitri2001 surd osv\n',
#  'memori network languag encod memori rule memori evolv time input sequenc oper nse access memori paper flexibl languag task languag infer question sentenc classif document sentiment analysi machin translat nse state art perform benchmark exampl memori model result machin translat attent baselin bleu\n',
#  'powerdynam packag time domain power grid stabil analysi system share energi use state art equat solver system number compon machin librari method optim paramet packag number model machin transmiss line system sourc approach macro interfac implement custom model design control strategi gener unit paper present concept model scenario measur lab tecnalia\n',
#  'model method abil remov redund paramet model perform method redund paramet paramet sensit gradient measur contribut paramet paper paramet contribut sensit contribut gap sensit sensit paramet gener perform contribut paramet goal balanc sensit paramet task method distil train loss balanc paramet sensit moreov design method control strength distil loss converg experi effect method machin translat languag understand shot cross transfer languag gain languag pair translat dataset\n',
#  'success comput vision languag process reinforc commun focu discoveri skill approach diayn dad inform propos approach function network behavior environ approach rang skill flip half humanoid pixel reveng environ method chang skill item locat implement approach http github com reinforc reward function\n',
#  'domain adapt uda data case manner chang e g weather chang condit network drop adapt contrast paper tackl onlin domain adapt segment design pipelin domain shift evalu case scenario experi domain domain\n',
#  'studi util translat model model text retriev variant end use model1 aggreg layer queri document approach design rank system benefit interpret model layer top bert embed decreas accuraci effici limit sequenc length model model bert model index time precomput queri time oper tensor model run document\n',
#  'key factor success avail benchmark research benchmark difficulti tracker perform introduct transform method lack scenario visibl weather condit effect avist scenario visibl avist challeng sequenc frame scenario attribut categori contribut avist divers scenario weather condit rain obstruct effect fire sun glare water imag effect target effect target object camouflag benchmark tracker analysi perform attribut room improv perform avist commun benchmark track solut order boundari state art dataset perform evalu http github com visionml\n',
#  'knowledg benefit recognit semant charact sequenc knowledg output sequenc method semant clue recognit paper introduc method multi modal text recognit network matrn interact featur recognit perform identifi featur pair inform featur featur featur modal stimul featur featur clue charact phase experi achiev state art perform benchmark margin combin modal improv studi effect compon implement http github com wp03052 matrn\n',
#  'actor algorithm evalu environ reward reveng maze vizdoom suit case montezuma reveng agent achiev result point experi world appropri choic hyperparamet surpass perform expert data number experi bug montezuma reveng point\n',
#  'knowledg model masteri estim hallmark learn research compon system paper histori knowledg model research introduc pybkt model extens data gener predict cross valid routin use data helper interfac tutor log dataset format dataset size implement saniti check experi data accuraci paramet learn use world data predict pybkt model variant result paper sourc licens purpos knowledg commun research practic progress field replic approach\n',
#  'reconstruct method shape polar literatur project assumpt case field view assumpt hold reconstruct error method assumpt address problem perspect phase angl ppa model perspect camera model model relationship polar phase surfac project addit model estim surfac normal view phase angl map suffer pi ambigu problem experi data model surfac estim perspect camera model\n',
#  'machin learn model sampl distribut failur distribut ood sampl class label reliabl model problem attent import safeti model world set ood sampl intract distribut date research domain problem detect sampl detect novelti detect class recognit distribut detect concept distribut detect research avenu research barrier overview approach domain relationship domain survey cross domain review emin work area common research research advanc field methodolog knowledg survey detect class date survey distribut detect survey cross domain discuss futur line research bring field\n',
#  'commonsens knowledg end end model word analog dataset permut hundr word dozen relat relat entiti model commonsens knowledg word level hownet ontolog word sens definit translat commonsens word analog analog word relat experi indic word represent knowledg dataset http github com ckiplab\n',
#  'ensembl process tangent kernel develop dynam network work limit interpret ensembl loss introduc modif ensembl addit function member enabl interpret limit approxim distribut ensembl predict ensembl limit nn demonstr ensembl predict standard distribut set regress classif task\n',
#  'paramet network architectur differ mediocr state art perform paramet design choic hyperparamet optim art experi paper evalu import network design choic hyperparamet sequenc task entiti recognit event detect setup paramet pre word embed layer network impact perform paramet exampl number layer number unit import recommend configur perform task\n',
#  'strategi train predict qualiti machin learn model task model architectur work introduc softwar framework treat data annot model method train compon modular access fine inform data set characterist match rule element model predict henc framework encompass rang train method supervis method correl rule output class machin model label har network data illustr framework perform comparison refer implement dataset framework sourc python packag http github com\n',
#  'classif algorithm help user machin model predict system hospit exampl let clinician patient infect classif system gap system time seri gap observ seri domain healthcar bridg gap classif time seri classifi door world problem hop time recurr network model time seri time irregular halt polici learn predict classifi seri step polici seri time way hop inform observ sourc classif time seri valu classif time seri world dataset hop predict state art altern problem code http github com thartvigsen stopandhop\n',
#  'inform extract openi method phrase relat phrase phrase tripl construct knowledg base phrase relat phrase kb storag fact research canonic kb featur space featur engin order overcom challeng canonic embed inform cesi novel approach perform canonic embed cesi advanc relat phrase side inform manner experi world dataset cesi effect\n',
#  'model diagnosi predict text result practic model provid doctor result novel method network attent abil predict part patient justif doctor model dataset baselin evalu doctor model explan decis support\n',
#  'imag problem solut scenario autoencod local function gener qualiti hash code method imag retriev applic number sampl gener hash code cost paper show sampl complex requir result retriev perform method autoencod approach sampl cost properti function discret space method wasserstein distanc comput wasserstein distanc approach order magnitud complex gener properti method addit cost approach conduct world method method improv state art imag method code paper github http github com hash\n',
#  'progress year studi graph network task cycl hint fact network catch inform structur downstream task substructur analysi chemistri correct standard gin convolut network cycl cost term comput time number paramet life molecul properti dataset perform multi dataset baselin task set\n',
#  'year represent popular reconstruct express flexibl represent result infer time paper revisit point cloud represent introduc point mesh layer formul poisson surfac reconstruct psr solut indic function point cloud psr layer bridg point represent indic field end optim surfac reconstruct metric distanc dualiti point mesh shape point cloud represent point model acceler infer time order magnitud represent point patch mesh topolog watertight manifold surfac sap task surfac reconstruct point cloud reconstruct\n',
#  'languag world knowledg scale knowledg graph knowledg entiti knowledg activ event entiti thing world fill gap aser activ event relat eventu knowledg graph token data aser relat type categori eventu edg evalu qualiti effect aser\n',
#  'consist model invari behavior altern properti languag paper studi question languag model respect knowledg end creat pararel qualiti resourc cloze style queri paraphras paraphras relat pararel show consist varianc relat space structur knowledg method model consist effect\n',
#  'cross view object aim object view overlap cross view object attent year dataset issu world scenario divers scene number track camera benchmark investig comparison cross view method issu cross view object dataset divers scene dens pedestrian environ scenario cross view track cross view object dataset baselin cross view method detect cross view framework crossmot learn detect view associ cross view model methodolog benchmark comparison conduct analysi approach crossmot dataset code http github com shengyuhao divotrack\n',
#  'point cloud model network architectur success safeti applic recognit system vehicl model attack transform rotat model predict paper propos transform framework tpc robust guarante model transform attack transform categori e g e g rotat e g robust certif strategi certif protocol transform composit experi transform state art exampl framework boost accuraci transform z axi circ code model github com qianhewu point cloud\n',
#  'contact app covid googl appl estim risk exposur order user precaut quarantin test risk score model paramet health author paper show paramet data method access exposur outcom data data privaci way health author paper limit data factor feasibl approach show estim data e g infect model misspecif approach outperform baselin furthermor approach factor chang e g evolut variant adopt vaccin\n',
#  'machin lot achiev comput vision task detect model resolut imag devic need method resolut data attent pipelin method evalu imag video frame rough resolut limit number evalu stage use detect model yolo v2 model code gpu accuraci perform fp video fp video\n',
#  'learn dl model increas model size accuraci gain network data parallel model parallel approach data parallel help memori footprint devic work convnet model parallel impact convnet size segment accuraci model parallel train convnet imag experi model parallel segment accuraci model size input context size input yield infer speedup window patch infer code footnot http monai research lamp model parallel\n',
#  'document level relat extract relat entiti sentenc method level supervis world scenario relat number entiti document level number entiti label problem propos learn framework shift loss ssr pu use pu document level time data dataset shift data introduc pu shift train data none class score threshold propos loss prove consist multi label metric experi achiev improv f1 point baselin addit outperform state art result set\n',
#  'progress reinforc suffer data ineffici gener effort learn learn meta learner rl task task way task level rl method model inform task limit abil task task paper captur inform hand meta learn inform task hand meta task encod task experi meanwhil learn polici task embed result task method capac train task time return baselin\n',
#  'increas demand network observ input sampl model interest input multi exit msdnet network faster infer power devic thing save approach pressur adversari slowdown dnn infer time threat servic attack paper conduct evalu threat multi exit dnn mobilenet resnet56 custom multi exit architectur imag classif end show exampl techniqu slowdown architectur slowdown attack reduc exit amplifi time iot deploy craft univers perturb box scenario knowledg victim train protect slowdown result research exit architectur threat code http github com sanghyun hong deepsloth\n',
#  'multi object mot aim box ident object method ident detect box score object detect score g object bring object trajectori problem associ method detect box score one score detect box similar tracklet object detect state art tracker achiev improv idf1 point forward state art perform mot design simpl tracker time mota idf1 test fp speed v100 gpu bytetrack state art perform mot20 bdd100k benchmark sourc code pre model version tutori tracker github com ifzhang bytetrack\n',
#  'imagin robot concept e g milk egg exampl class set instanc object milk label speech input instanc shot exampl modal class exampl shot contribut task baselin model digit advanc network model achiev model distanc imag time speech way cross modal\n',
#  'fractur area wider rang motion joint reason fractur data xradiat x ray reson mri tomographi ct studi physician shoulder imag ray devic fractur intellig perform learn model detect shoulder fractur radiograph mura model model resnet densenet vgg incept mobilenet fc version model model perform test accuraci cohen area class receiv roc curv result classif test accuraci valu model valu model\n',
#  'problem inaccur target draw attent work solv problem predict indic bin count valu set count error contribut interv perform count partit criterion error partit uep error contribut interv predict risk mitig discret error quantiz process criterion count proxi criterion select count interv repres count valu infer discret error imag work classif task solut count partit criterion model error partit network achiev state art perform dataset http github com tencentyouturesearch uepnet\n',
#  'cycl cycl network c2gan hand bodi scene cross modal model exploit input imag data guidanc data manner gener imag gener gener guidanc gener gener gener end fashion subnet imag gener cycl guidanc gener cycl cycl input domain output gener cycl way cycl inform imag guidanc modal supervis gradient cycl optim model result imag imag translat subtask imag state art model http github com ha0tang c2gan\n',
#  'queri optim perform compon databas system complex optim expert month year work demonstr time queri optim balsa queri optim reinforc balsa knowledg environ simul execut join order benchmark balsa match perform queri optim sourc hour outperform time runtim hour possibl comput environ optim\n',
#  'gnn paradigm architectur facilit learn multi agent behavior work perform task multi path plan coverag polici gnn scheme world multi robot system design system execut gnn polici framework elabor detail paper demonstr framework case studi coordin robot kind result world deploy gnn polici system commun video demonstr case studi sourc code repositori http www youtub com watch v coh wln4io4 http github com proroklab ros2 multi agent passag http github com proroklab rl multi agent passag\n',
#  'crowd way peopl scene imag vision crowd count approach captur featur condit night occlus work introduc task crowd auditori inform count purpos scale benchmark crowd dataset imag clip instanc order modal use featur wise fusion modul transform auditori featur experi dataset approach result inform benefit crowd illumin nois occlus condit code code data\n',
#  'learn method promis domain adapt leverag sourc domain target domain distribut method domain represent space distribut sourc target level structur paper cluster align teacher cat domain adapt cluster structur adapt leverag teacher model class structur featur space target domain cat forc sourc target class cluster cluster domain result achiev state art result domain adapt scenario\n',
#  'abil model text nlp applic correct step downstream process prevent languag model paper propos gram damerau levenshtein distanc model rule extract model sampl train data achiev perform outperform approach term edit distanc power train time success approach learn model set data\n',
#  'prompt imag model imag prompt input engin propos adapt framework user input model prompt perform tune languag model collect prompt learn prompt function polici gener imag intent result diffus show method prompt engin term metric prefer rate boost perform prompt checkpoint aka ms demo aka ms demo\n',
#  'network data imag data tree model properti tree model interpret work decis tree model network tree network nn toolkit descent dataset efficaci similar differ decis tree featur level\n',
#  'state art network normal featur attent perform improv amount task modul paper integr schema normal affin transform transform affin transform featur instanc way weight channel wise featur attent experi architectur classif benchmark ms coco detect instanc segment benchmark perform improv architectur benchmark increas accuraci imagenet increas bound box mask ap ms coco squeez excit modul sourc code http github com aognet v2 imagenet classif repo http github com ivmcl attentivenorm detect ms coco detect segment repo\n',
#  'attack work phenomenon train gener gap test train accuraci network gener gap choic activ function show function curvatur valu effect gener gap train observ effect activ activ case curvatur activ function curvatur descent phenomenon model\n',
#  'work concern risk correl bias machin learn model robust paper regular approach integr causal knowledg model model featur featur causal featur principl framework causal infer regular approach penal causal featur strength penalti type featur model reli featur causal featur experi model robust dataset metric result model awar model robust text model respect attribut\n',
#  'end learn framework imag imag composit object patch object imag background scene imag approach coher imag rgb accuraci input output network structur featur design network loss self network layout featur imag featur edg input patch code input affin transform translat patch paramet transform network transform object patch target imag model transform discrimin layout discrimin evalu network sac gan imag composit scenario term compos generaliz imag comparison state art altern instanc insert st gan placenet superior method\n',
#  'method tag multiword express languag learn architectur discontinu aspect pose treatment mwe architectur network gcn multi head attent gcn depend pars inform attent rang relat model inform mechan experi dataset mwe show model baselin case mwe f score\n',
#  'meta method shot entiti recognit ner method class vector number sampl class semant problem metnet gener vector type class design triplet network map sampl vector space margin entiti margin play control region size space region infer procedur label queri instanc conduct experi cross domain set metnet state art method releas shot ner dataset comm e commerc platform knowledg shot ner dataset code github com hccngu metnet\n',
#  'work qualiti measur model incept incept distanc vulner model attack metric pixel perturb experi gener distribut imag score qualiti optim perturb world imag score evalu model state art network styleganv2 show vulner model perturb space incept incept valid effect experi manipul\n',
#  'onlin learn improv perform classif branch regress branch design requir qualiti sampl issu onlin framework focu classif regress branch target filter paradigm contribut introduc regress model gener rmg weight target filter onlin sampl target filter weight groundtruth sampl rgm devis anchor tracker fcot featur backbon decod multi classif branch multi scale regress branch thank design rmg handl target variat dimens result issu error accumul procedur addit simplic design fcot manner time speed fcot state art perform benchmark vot2018 trackingnet otb100 code model http github com mcg nju fcot\n',
#  'method view makeup transfer color distribut region detail eye blush transfer region paper makeup detail step toward control makeup transfer attribut featur preserv frequenc inform attent extract makeup featur sourc face sow attent modul appli attent window cost moreov area featur map experi gener makeup detail achiev state art perform code http github com chenyu yang eleg\n',
#  'reinforc method perform multi agent task research direct valu function decomposit agent polici gradient paper multi agent actor msac method advantag method modul network architectur polici advantag function support effici polici address credit assign problem action space starcraft ii micromanag multiag benchmark perform msac variant effect compon result msac polici approach coma achiev result valu approach qmix task term perfom addit msac achiev result action space task vs mmm2\n',
#  'deep learn face recognit method perform resolut face pixel camera face resolut inform face ident resolut galleri find end propos resolut model rim cross resolut face recognit problem novelti architectur face hallucin fhn recognit hrn end fhn path network gan structur geometri inform e landmark heatmap map cross domain train strategi resolv resolut queri imag one hrn network face recognit knowledg distil strategi featur represent experi benchmark superior model state art code model accept\n',
#  'popular advantag dens retriev method abil salient phrase entiti domain data limit dens model claim phrase retriev spar dens capac spars model show model lambda spars spar dens retriev show perform rang task question dataset passag retriev well entityquest benchmark evalu perform state art dens spars retriev model http github com facebookresearch dpr scale tree spar\n',
#  'segment loss variant ce dice loss segment literatur consensu loss choic perform benchmark applic analysi link type loss advantag weak optim perspect dice share connect penalti ground truth penalti relationship inform analysi label bias bia toward solut ground truth region proport result evid imag literatur dice loss improv segment ce imag problem class proport case dice distribut analysi propos solut enabl bia loss l regular encourag margin target class proport class imbal gener experi ablat studi loss applic analysi label regular\n',
#  'object imag learn method classifi mr imag plane post process effici method vendor mri studi centr vendor network cardisort sequenc sequenc plane vendor train svt centr imag patient train mvt multicentr imag patient centr model accuraci ground truth label test svt valid data magnet system vendor patient result sequenc plane accuraci test mvtextern sequenc accuraci plane accuraci accuraci sequenc plane accuraci class sequenc variabl acquisit paramet centr conclus network multivendor data studi sequenc valid refin improv workflow sequenc select step post process pipelin\n',
#  'multi label classif exampl dataset none exampl applic imag document tag appli imag class data annot error data practic consid exampl classif dataset extens framework qualiti score rank error approach methodolog label error detect approach error imag tag dataset\n',
#  'framework kullback leibler kl term class object prototyp graph solut term approach trade level object upper bound decomposit term properti pinsker inequ bound object solut converg guarante iter perform assign dataset scalabl enabl trade level object relax formul decomposit report evalu comparison state art method benchmark formul yield solut term object\n',
#  'shot entiti recognit system class entiti exampl paper present meta approach address problem shot shot span detect shot entiti meta shot span detect sequenc label problem train span detector model meta model paramet initi entiti class entiti protonet e maml network space text span represent entiti class experi benchmark approach achiev perform method\n',
#  'quantum control quantum implement technolog control paramet use simul solut tabl machin model result effici method model hardwar acceler use quantum system machin puls paramet resourc fpga perform infer latenc pipelin interv gate fidel term acceler comput quantum control cost latenc data bandwidth environ\n',
#  'decad recognit hcr problem pattern recognit research script model similar structur charact style dataset divers research extract techniqu dataset repositori result hand learn success area recognit hcr end techniqu data train script limit deep learn script charact recognit hcr net novel transfer approach hcr featur extract layer network transfer imag augment perform gener dataset dataset hindi farsi tibetan kannada malayalam telugu marathi languag benchmark result result case perform improv result converg rate perform net state art transfer learn techniqu\n',
#  'network imag classif model treat box evalu dataset strategi classifi instanc evalu dataset perform measur accuraci precis recal sampl error predict confid error mistak past work search techniqu error confid threshold ignor fact error confid level work investig problem error rate confid queri effici search techniqu perturb box model experiment demonstr distanc search discov confid error rate model confid\n',
#  'architectur search na attent class input space network architectur part na pipelin architectur block oper approach captur properti hand vector encod oper inform paper propos replac oper represent optim process approach relat oper represent perform end task evalu ena benchmark oper embed gener model state art perform perform architectur share oper graph pattern correl properti perform\n',
#  'state art summar model input text model way address problem post edit summari approach entiti error entiti replac work focu entiti error entiti sourc consist inform form propos use sentenc compress data post edit model entiti error token output error show model consist roug entiti precis model post editor entiti precis perform comparison post approach trade off consist inform grammat set post editor improv\n',
#  'detect method scenario line topolog condlanenet novel lane detect framework detect lane instanc line shape instanc resolv instanc level discrimin problem lane detect strategi convolut row wise formul design recurr instanc modul overcom problem line topolog line fork line end pipelin post process method time effici method benchmark detect result achiev state art perform benchmark dataset coexist accuraci effici f1 score fp culan code http github com lane detect\n',
#  'imag formul task class imag becom imag sampl imag imag subspac imag resolut imag subspac problem address formul imag resolut problem fact imag resolut task imag ground truth resolut imag produc sampl resolut imag input method gener lag sampl framework use input resolut class sampl network output algorithm imag se imag imag space adversari loss pixel loss\n',
#  'intent slot key problem languag context zero shot task represent transform machin sourc data target languag work scenario target languag train goal method augment sourc data code translat languag neutral downstream task method insight languag famili world impact perform target languag experi dataset multiati improv accuraci intent task f1 slot task state art languag applic method crisi informat tweet dataset slot creol earthquak disast\n']

# %%
n_features = 100 # Extract 100 feature words
tf_vectorizer = CountVectorizer(strip_accents = 'unicode',
                                max_features=n_features,
                                stop_words='english',
                                max_df = 0.3,
                                min_df = 10)
tf = tf_vectorizer.fit_transform(docLst)
dump(tf_vectorizer,tf_ModelPath)
# Out:
# ['../abstract_model/abstract_tf.pt']

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tfidf_vectorizer = TfidfTransformer()
tfidf = tfidf_vectorizer.fit_transform(tf)
dump(tfidf_vectorizer,tfidf_ModelPath)
# Out:
# ['../abstract_model/abstract_tfidf.pt']

# %%
# load tf and tfidf
tfidf_vectorizer = load(tfidf_ModelPath)
tf_vectorizer = load(tf_ModelPath)
tf = tf_vectorizer.transform(docLst)
tfidf = tfidf_vectorizer.transform(tf)

# %%
import time
def train_lda(n_t):
    lda = LatentDirichletAllocation(max_iter=100000, learning_method="batch", learning_offset=50, n_jobs=-1, doc_topic_prior=0.04163183877389392,
                                        n_components=n_t, topic_word_prior=0.04911253614440047)
    start_time = time.time()
    lda.fit(tfidf)
    end_time = time.time()
    print("LDA_" + str(n_t)+":")
    print("time:", end_time - start_time)
    dump(lda,lda_ModelPath + "lda_" + str(n_t) + ".pt")
    print("Perplexity:", lda.perplexity(tfidf))
    print("Score:", lda.score(tfidf))
    print("---------------------------------------------")

# %%
for n_t in n_topics:
    train_lda(n_t)
# Out:
# LDA_10:
# time: 1.173313856124878
# Perplexity: 1918.26601842532
# Score: -1975.6418121387933
# ---------------------------------------------
# LDA_20:
# time: 0.02712559700012207
# Perplexity: 4938.901867131857
# Score: -2222.8124572697575
# ---------------------------------------------
# LDA_27:
# time: 0.025438785552978516
# Perplexity: 5482.279977245669
# Score: -2250.0923653694144
# ---------------------------------------------
# LDA_30:
# time: 0.024245262145996094
# Perplexity: 6241.724699499213
# Score: -2283.999604262288
# ---------------------------------------------
